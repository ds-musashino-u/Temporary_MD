# %% [markdown]
# ### MD no.8 vol.1
# - pandasでcsvファイルの読み込み、データフレームとして格納
# - csvファイル：datasets/class_score.csv
# - matplotlibとseabornので棒グラフ表示

# %%
# pandas matplotlib seabornのimport

# 'datasets/class_scores.csv'ファイルの読み込み

# 先頭部分のデータ確認
# Out:
#    Class A  Class B  Class C  Class D
# 0       87      100       72       78
# 1       74       37       75       93
# 2       79       40      100       84
# 3       92      100       93       81
# 4       88       43       92       88

# %%
# データの統計情報を確認
# Out:
#           Class A     Class B     Class C    Class D
# count  100.000000  100.000000  100.000000  100.00000
# mean    70.090000   77.510000   77.060000   83.53000
# std     10.128562   24.336652   16.885126    4.69785
# min     44.000000    7.000000   24.000000   71.00000
# 25%     63.000000   58.000000   68.000000   81.00000
# 50%     70.500000   85.500000   78.000000   83.00000
# 75%     77.000000  100.000000   90.250000   87.00000
# max     92.000000  100.000000  100.000000   96.00000

# %%
# pandasの標準機能によってとりあえずグラフ表示してみるが、折れ線グラフは適切ではない（学生間のデータには連続性はないので）
# Out:
# <Axes: >

# %%
# グラフの種類を「bar：棒グラフ」を指定しても適切なグラフは表示されない
# Out:
# <Axes: >

# %%
# Y軸のラベルを設定


# seabornライブラリによって適切な棒グラフを表示できる
# Out:
# <Axes: ylabel='Score'>
