# %% [markdown]
# ### MD no.8 vol.2
# - pandasでcsvファイルの読み込み、データフレームとして格納
# - csvファイル：datasets/height_weight.csv
# - matplotlibとseabornので棒グラフ表示

# %%
# pandas matplotlib seabornのimport

# 'datasets/class_scores.csv'ファイルの読み込み

# 先頭部分のデータ確認
# Out:
#     国  身長(cm)  体重(kg)
# 0  日本     172      65
# 1  日本     167      56
# 2  日本     178      74
# 3  日本     164      50
# 4  日本     175      69

# %%
# データの統計情報を確認
# Out:
#            身長(cm)    体重(kg)
# count   25.000000  25.00000
# mean   175.960000  71.56000
# std      8.192883  12.15552
# min    163.000000  50.00000
# 25%    171.000000  64.00000
# 50%    175.000000  70.00000
# 75%    180.000000  80.00000
# max    195.000000  97.00000

# %%
# pandasの標準機能によってとりあえずグラフ表示してみるが、折れ線グラフは適切ではない（学生間のデータには連続性はないので）
# Out:
# <Axes: >

# %%
# グラフの種類を「bar：棒グラフ」を指定しても適切なグラフは表示されない
# Out:
# <Axes: >

# %%
# グラフ設定

# 左のy軸で身長のボックスプロットを作成

# 右のy軸を作成


# 右のy軸で体重のボックスプロットを作成

# %%
# グラフ設定

# 左のy軸で身長のボックスプロットを作成
# Out:
# Text(0, 0.5, '身長(cm)')

# %%
# グラフ設定


# 左のy軸で身長のボックスプロットを作成
# Out:
# Text(0, 0.5, '体重(kg)')
