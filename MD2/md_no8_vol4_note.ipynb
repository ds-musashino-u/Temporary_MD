# %% [markdown]
# ### MD no.8 vol.4
# - pandasでcsvファイルの読み込み、データフレームとして格納
# - csvファイル：datasets/throw_speed.csv
# - matplotlibとseabornので棒グラフ表示

# %%
# pandas matplotlib seabornのimport


# 'datasets/class_scores.csv'ファイルの読み込み


# 先頭部分のデータ確認
# Out:
#          date        speed
# 0  2019/05/22   Speed: 109
# 1  2019/06/22   Speed: 110
# 2  2019/07/22   Speed: 108
# 3  2019/08/22   Speed: 110
# 4  2019/09/22   Speed: 111

# %%
# データの統計情報を確認したいが、このままでは確認できない
# Out:
#               date        speed
# count           44           44
# unique          44           29
# top     2019/05/22   Speed: 112
# freq             1            5

# %%
# speed列に含まれた文字列「Speed:」を削除する（空文字に置き換える）
# Out:
#          date speed
# 0  2019/05/22   109
# 1  2019/06/22   110
# 2  2019/07/22   108
# 3  2019/08/22   110
# 4  2019/09/22   111

# %%
# df['speed']を文字列から数値（小数）に変換
# Out:
#          date  speed
# 0  2019/05/22  109.0
# 1  2019/06/22  110.0
# 2  2019/07/22  108.0
# 3  2019/08/22  110.0
# 4  2019/09/22  111.0

# %%
# df['date']は文字列なので日付・時刻型に変換する
# Out:
#         date  speed
# 0 2019-05-22  109.0
# 1 2019-06-22  110.0
# 2 2019-07-22  108.0
# 3 2019-08-22  110.0
# 4 2019-09-22  111.0

# %%
# 改めて統計情報確認
df.describe()
# Out:
#                                 date        speed
# count                             44    44.000000
# mean   2021-03-07 14:10:54.545454592   177.545455
# min              2019-05-22 00:00:00   108.000000
# 25%              2020-04-14 06:00:00   111.750000
# 50%              2021-03-08 00:00:00   116.500000
# 75%              2022-01-29 18:00:00   140.500000
# max              2022-12-22 00:00:00  1390.000000
# std                              NaN   250.982576

# %%
# 折れ線グラフの表示
# Out:
# <Axes: xlabel='date', ylabel='speed [km]'>

# %%
# 異常値（外れ値）の除去
# データ数が少ない場合はthrow_speed.csvをコピー（生データを直接編集しない）
# コピーしたデータから該当箇所を手動で取り除く

# データ数が多い場合は以下の手順で外れ値を自動的に検出・除去する
# speedの平均値と標準偏差を算出

# 平均値との差が標準偏差の3倍以内だったデータのみを抽出し、clead_dfに格納
# dfの中に条件式を入れるとデータフレームの中から該当したデータのみを抽出できる

# clean_dfが外れ値を除去したデータ
# Out:
#          date  speed
# 0  2019-05-22  109.0
# 1  2019-06-22  110.0
# 2  2019-07-22  108.0
# 3  2019-08-22  110.0
# 4  2019-09-22  111.0
# 5  2019-10-22  109.0
# 6  2019-11-22  112.0
# 7  2019-12-22  114.0
# 8  2020-01-22  110.0
# 9  2020-02-22  112.0
# 10 2020-03-22  113.0
# 11 2020-04-22  111.0
# 12 2020-05-22  112.0
# 13 2020-06-22  110.0
# 14 2020-07-22  112.0
# 15 2020-08-22  111.0
# 16 2020-09-22  109.0
# 17 2020-10-22  112.0
# 19 2020-12-22  114.0
# 20 2021-01-22  113.0
# 21 2021-02-22  115.0
# 22 2021-03-22  116.0
# 23 2021-04-22  117.0
# 24 2021-05-22  119.0
# 25 2021-06-22  123.0
# 26 2021-07-22  128.0
# 27 2021-08-22  133.0
# 28 2021-09-22  130.0
# 29 2021-10-22  129.0
# 30 2021-11-22  131.0
# 31 2021-12-22  138.0
# 32 2022-01-22  139.0
# 33 2022-02-22  140.0
# 34 2022-03-22  142.0
# 35 2022-04-22  143.0
# 36 2022-05-22  144.0
# 37 2022-06-22  143.0
# 39 2022-08-22  145.0
# 40 2022-09-22  149.0
# 41 2022-10-22  148.0
# 42 2022-11-22  150.0
# 43 2022-12-22  148.0

# %%
# 再度、折れ線グラフ表示
# Out:
# <Axes: xlabel='Measurement Date [YY:MM:DD]', ylabel='Speed [km]'>

# %%
# ヒストグラムを表示


# このデータではあまり有用性はないが、ヒストグラムからもspeedが上がらず苦労したことが分かる
